# %%
import pandas as pd
from transformers import pipeline
import numpy as np
import os

# Check if the file exists
file_path = r"C:\Users\admin\Desktop\traini\article.xlsx"
if not os.path.exists(file_path):
    print(f"File not found: {file_path}")
else:
    print(f"File found: {file_path}")

# Load your dataset from Excel
try:
    data = pd.read_excel(file_path)
    print("Excel file loaded successfully")
except Exception as e:
    print(f"Error loading Excel file: {e}")

# Check the first few rows to confirm the columns
print("DataFrame head:")
print(data.head())

# Verify the column names
print("DataFrame columns:")
print(data.columns)

# Predefined order of labels
Categories = [
    "Equity Financing", "Debt Financing", "IPO", "Bankruptcy/financial distress", "financial results", 
    "ESG announcement", "credit rating", "Joint venture", "New product launch", "Investment", 
    "New project announcement", "Project update", "Contract Announcements", "R&D, Patent, copyrights, Trademark updates",
    "Price & Promotion updates", "Product recall", "Senior executive hiring", "Layoffs and downsizing",
    "Currency News", "International Trade Updates", "Stock market updates", "Corporate Legal Affairs", 
    "Regulatory News", "Merger & Acquisition"
]

# Load the pre-trained zero-shot classifier
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

def classify_titles(titles):
    classified_results = []
    
    for title in titles:
        result = classifier(title, Categories)
        best_category = result['labels'][0]
        best_score = result['scores'][0]
        classified_results.append((title, best_category, best_score))
        
    return classified_results

# Combine title and first 100 words of the article for classification
def get_combined_text(row):
    title = row['text']
    #article = row['article']
    #first_100_words = ' '.join(article.split()[:100])
    return f"{title}" 

# Ensure columns exist before applying the function
if 'text' in data.columns and 'article' in data.columns:
    # Apply the function to get combined texts
    data['combined_text'] = data.apply(get_combined_text, axis=1)

    # Titles to classify
    titles_to_classify = data['combined_text'].tolist()
    classified_titles = classify_titles(titles_to_classify)

    # Print the results with only the title
    for idx, (combined_text, category, confidence) in enumerate(classified_titles):
        title = data.loc[idx, 'text']
        print(f"Title: '{title}' is classified as '{category}' with confidence score {confidence:.4f}")
else:
    print("Required columns 'text' and/or 'article' not found in the DataFrame.")
# Out:
# File found: C:\Users\admin\Desktop\traini\article.xlsx
# Excel file loaded successfully
# DataFrame head:
#                                                 text  \
# 0  Exclusive: Boeing deliveries to China delayed ...
# 1  Not all Fed officials favored tapering of bala...
# 2  Target, Walmart shoppers seek home goods, groc...
# 3  Exclusive: Boeing deliveries to China delayed ...
# 4  Putin approves closure of American Express Rus...
#
#                                              article
# 0  May 22 (Reuters) - Boeing's  plane deliveries ...
# 1  NEW YORK, May 22 (Reuters) - Meeting minutes f...
# 2  NEW YORK, May 22 (Reuters) - U.S. online spend...
# 3  May 22 (Reuters) - Boeing's  plane deliveries ...
# 4  MOSCOW, May 22 (Reuters) - Russian President V...
# DataFrame columns:
# Index(['text', 'article'], dtype='object')
# Title: 'Exclusive: Boeing deliveries to China delayed by state regulator review, source says' is classified as 'Regulatory News' with confidence score 0.2811
# Title: 'Not all Fed officials favored tapering of balance sheet contraction process' is classified as 'Project update' with confidence score 0.0723
# Title: 'Target, Walmart shoppers seek home goods, grocery delivery online' is classified as 'Joint venture' with confidence score 0.6850
# Title: 'Exclusive: Boeing deliveries to China delayed by state regulator review, source says' is classified as 'Regulatory News' with confidence score 0.2811
# Title: 'Putin approves closure of American Express Russian business' is classified as 'Layoffs and downsizing' with confidence score 0.1820
# Title: 'AI disclosure required in campaign ads, FCC chair says' is classified as 'Regulatory News' with confidence score 0.2375
# Title: 'S&P 500 to end 2024 around current levels after strong run: Reuters poll' is classified as 'Stock market updates' with confidence score 0.3247
# Title: 'Cancer victims sue Johnson & Johnson over 'fraudulent' bankruptcies' is classified as 'financial results' with confidence score 0.4941
# Title: 'Fed shifts talk to 'scenarios' as policy grows less certain' is classified as 'Regulatory News' with confidence score 0.1024
# Title: 'Argentine black market peso hits record low as Milei rally falters' is classified as 'financial results' with confidence score 0.3020
# Title: 'US lawmakers advance bill to make it easier to curb exports of AI models' is classified as 'International Trade Updates' with confidence score 0.1404
# Title: 'Anglo leaves door open to engage with BHP after spurning third offer' is classified as 'Merger & Acquisition' with confidence score 0.1156
# Title: 'Lagardere says it is closing in on sale of Paris Match magazine to LVMH' is classified as 'Merger & Acquisition' with confidence score 0.1658
# Title: 'Reuters Events: CSX fully resuming Baltimore coal exports this week, CEO says' is classified as 'Regulatory News' with confidence score 0.4322
# Title: 'Disney strikes deal to sell stake in India's Tata Play, Bloomberg News reports' is classified as 'Merger & Acquisition' with confidence score 0.1214
# Title: 'FTX's Bankman-Fried being transferred to new prison, WSJ reports' is classified as 'Bankruptcy/financial distress' with confidence score 0.1993
# Title: 'Petrobras says antitrust watchdog agreed to free company from asset sales' is classified as 'ESG announcement' with confidence score 0.1671
# Title: 'Brazil's Haddad says monetary policy still 'very restrictive'' is classified as 'financial results' with confidence score 0.2163
# Title: 'Volkswagen delays ID.7 EV launch in US, Canada' is classified as 'New product launch' with confidence score 0.3270
# Title: 'Bristol Myers, Sanofi liability in Hawaii Plavix case grows to $916 million' is classified as 'financial results' with confidence score 0.3006
# Title: 'Americans keep vehicles for record 12.6 years on average despite easing supplies, S&P says' is classified as 'ESG announcement' with confidence score 0.1035
# Title: 'SocGen CEO: cross-border mergers between European banks are structurally unlikely' is classified as 'ESG announcement' with confidence score 0.1410
# Title: 'Carlyle Group exits Brazil's Rede D'Or -reports' is classified as 'Investment' with confidence score 0.2099
# Title: 'Explainer: What New Caledonia riots mean for the nickel industry' is classified as 'ESG announcement' with confidence score 0.1707
# Title: 'Saudi woos electric flying taxi company Archer as Gulf rivals vie to be aviation hub' is classified as 'Joint venture' with confidence score 0.1199
# Title: 'Intercontinental Exchange to pay $10 mln penalty over cyber intrusion' is classified as 'ESG announcement' with confidence score 0.2058
# Title: 'EEX, Nasdaq deal triggers EU concerns about bundled products, price hikes' is classified as 'Joint venture' with confidence score 0.5462
# Title: 'Earnings from AI-heavyweight Nvidia to test US stocks’ record run' is classified as 'financial results' with confidence score 0.5245
# Title: 'China's local govt bodies ask Evergrande EV unit to return $262.4 mln subsidies' is classified as 'financial results' with confidence score 0.1390
# Title: 'BHP-Anglo prospects flag more M&A ahead for miners' is classified as 'Merger & Acquisition' with confidence score 0.8116
# Title: 'WisdomTree, 21Shares to list crypto products on London Stock Exchange' is classified as 'Joint venture' with confidence score 0.3161
# Title: 'Thousands of Argentine builders laid off as Milei slashes state spending' is classified as 'Layoffs and downsizing' with confidence score 0.5117
# Title: 'Nigerian court adjourns Binance, executives' tax evasion trial to June 14' is classified as 'financial results' with confidence score 0.1342
# Title: 'Shell sees emerging Asian markets taking more of world's growing LNG supply' is classified as 'ESG announcement' with confidence score 0.1574
# Title: 'Off-price retailer TJX lifts annual profit forecast on strong demand, lower costs' is classified as 'financial results' with confidence score 0.6577
# Title: 'European Commission official sees $100 bln in private chip investment by 2030' is classified as 'Investment' with confidence score 0.2723
# Title: 'Biogen in up to $1.8 bln deal as rare diseases take center stage' is classified as 'financial results' with confidence score 0.2095
# Title: 'Several Chinese cities slash down payments, mortgage rates to boost property demand' is classified as 'financial results' with confidence score 0.1534
# Title: 'Analog Devices forecasts robust quarterly revenue on chip market recovery' is classified as 'financial results' with confidence score 0.5982
# Title: 'Exiled Chinese businessman Guo Wengui goes on trial for fraud' is classified as 'financial results' with confidence score 0.1301
# Title: 'US DOJ could seek break up of Live Nation, Bloomberg News reports' is classified as 'Currency News' with confidence score 0.1429
# Title: 'Stocks fall after Fed minutes; Nvidia shares climb after the bell' is classified as 'Stock market updates' with confidence score 0.6161
# Title: 'Bridgewater taps China head Alpert to oversee new investment unit' is classified as 'Senior executive hiring' with confidence score 0.4730
